# %% [markdown]
# # Import Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
with open("./traffic-signs-data/train.p", mode='rb') as training_data:
    train = pickle.load(training_data)
with open("./traffic-signs-data/valid.p", mode='rb') as validation_data:
    valid = pickle.load(validation_data)
with open("./traffic-signs-data/test.p", mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
X_train.shape
# Out:
# (34799, 32, 32, 3)

# %%
y_train.shape
# Out:
# (34799,)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %%
y_validation.shape
# Out:
# (4410,)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
y_test.shape
# Out:
# (12630,)

# %% [markdown]
# # Image Exploration

# %%
i = 1000
plt.imshow(X_train[i])
y_train[i]
# Out:
# 36

# %%
j = 1000
plt.imshow(X_validation[j])
y_validation[j]
# Out:
# 4

# %%
k = 1000
plt.imshow(X_test[k])
y_test[k]
# Out:
# 17

# %% [markdown]
# # Data Preparation

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_validation_gray = np.sum(X_validation/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray-128)/128
X_validation_gray_norm = (X_validation_gray-128)/128
X_test_gray_norm = (X_test_gray-128)/128

# %%
X_train_gray_norm
# Out:
# array([[[[-0.0546875 ],
#          [ 0.00260417],
#          [ 0.00260417],
#          ...,
#          [-0.43489583],
#          [-0.61979167],
#          [-0.71354167]],
#
#         [[ 0.109375  ],
#          [ 0.19270833],
#          [ 0.13020833],
#          ...,
#          [-0.08333333],
#          [-0.13541667],
#          [-0.24739583]],
#
#         [[ 0.1796875 ],
#          [ 0.09375   ],
#          [-0.01041667],
#          ...,
#          [-0.34375   ],
#          [-0.17447917],
#          [-0.16927083]],
#
#         ...,
#
#         [[-0.62239583],
#          [-0.7265625 ],
#          [-0.75520833],
#          ...,
#          [-0.69270833],
#          [-0.71354167],
#          [-0.71614583]],
#
#         [[-0.66927083],
#          [-0.703125  ],
#          [-0.72916667],
#          ...,
#          [-0.7421875 ],
#          [-0.75      ],
#          [-0.73958333]],
#
#         [[-0.6796875 ],
#          [-0.67708333],
#          [-0.69010417],
#          ...,
#          [-0.65885417],
#          [-0.6640625 ],
#          [-0.68489583]]],
#
#
#        [[[-0.08854167],
#          [ 0.19791667],
#          [ 0.48177083],
#          ...,
#          [-0.2734375 ],
#          [-0.24479167],
#          [-0.28125   ]],
#
#         [[-0.29947917],
#          [-0.16927083],
#          [ 0.13020833],
#          ...,
#          [-0.32552083],
#          [-0.30208333],
#          [-0.27604167]],
#
#         [[-0.26302083],
#          [-0.40625   ],
#          [-0.12760417],
#          ...,
#          [-0.3046875 ],
#          [-0.3203125 ],
#          [-0.30989583]],
#
#         ...,
#
#         [[-0.47395833],
#          [-0.57552083],
#          [-0.47395833],
#          ...,
#          [-0.453125  ],
#          [-0.453125  ],
#          [-0.421875  ]],
#
#         [[-0.56770833],
#          [-0.59114583],
#          [-0.56770833],
#          ...,
#          [-0.45052083],
#          [-0.45833333],
#          [-0.44270833]],
#
#         [[-0.38802083],
#          [-0.55208333],
#          [-0.56510417],
#          ...,
#          [-0.48177083],
#          [-0.484375  ],
#          [-0.46614583]]],
#
#
#        [[[ 0.8046875 ],
#          [ 0.5625    ],
#          [ 0.4375    ],
#          ...,
#          [-0.65885417],
#          [-0.67447917],
#          [-0.515625  ]],
#
#         [[ 0.9140625 ],
#          [ 0.77864583],
#          [ 0.72135417],
#          ...,
#          [-0.6484375 ],
#          [-0.703125  ],
#          [-0.54427083]],
#
#         [[ 0.95572917],
#          [ 0.828125  ],
#          [ 0.6015625 ],
#          ...,
#          [-0.45052083],
#          [-0.52864583],
#          [-0.56510417]],
#
#         ...,
#
#         [[ 0.97395833],
#          [ 0.953125  ],
#          [ 0.953125  ],
#          ...,
#          [-0.3515625 ],
#          [-0.3671875 ],
#          [-0.36979167]],
#
#         [[ 0.1328125 ],
#          [-0.02083333],
#          [-0.05989583],
#          ...,
#          [-0.76822917],
#          [-0.796875  ],
#          [-0.81510417]],
#
#         [[-0.58072917],
#          [-0.62239583],
#          [-0.6171875 ],
#          ...,
#          [-0.84114583],
#          [-0.8359375 ],
#          [-0.828125  ]]],
#
#
#        ...,
#
#
#        [[[ 0.9921875 ],
#          [ 0.98958333],
#          [ 0.8203125 ],
#          ...,
#          [ 0.078125  ],
#          [ 0.10416667],
#          [ 0.07552083]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.84895833],
#          ...,
#          [ 0.05729167],
#          [ 0.0703125 ],
#          [ 0.1015625 ]],
#
#         [[ 0.9921875 ],
#          [ 0.9921875 ],
#          [ 0.8828125 ],
#          ...,
#          [ 0.08072917],
#          [ 0.06770833],
#          [ 0.09635417]],
#
#         ...,
#
#         [[ 0.40104167],
#          [ 0.36979167],
#          [ 0.21875   ],
#          ...,
#          [-0.78645833],
#          [-0.8046875 ],
#          [-0.80208333]],
#
#         [[-0.68229167],
#          [-0.70052083],
#          [-0.72916667],
#          ...,
#          [-0.79427083],
#          [-0.80729167],
#          [-0.8046875 ]],
#
#         [[-0.80989583],
#          [-0.80729167],
#          [-0.81510417],
#          ...,
#          [-0.8125    ],
#          [-0.83072917],
#          [-0.83072917]]],
#
#
#        [[[-0.78645833],
#          [-0.77604167],
#          [-0.5390625 ],
#          ...,
#          [-0.65625   ],
#          [-0.63802083],
#          [-0.64322917]],
#
#         [[-0.79427083],
#          [-0.77604167],
#          [-0.5390625 ],
#          ...,
#          [-0.66666667],
#          [-0.64322917],
#          [-0.671875  ]],
#
#         [[-0.81770833],
#          [-0.796875  ],
#          [-0.58072917],
#          ...,
#          [-0.68229167],
#          [-0.671875  ],
#          [-0.66927083]],
#
#         ...,
#
#         [[-0.80989583],
#          [-0.79166667],
#          [-0.8203125 ],
#          ...,
#          [-0.8046875 ],
#          [-0.8125    ],
#          [-0.83333333]],
#
#         [[-0.8125    ],
#          [-0.78125   ],
#          [-0.8125    ],
#          ...,
#          [-0.8203125 ],
#          [-0.796875  ],
#          [-0.81510417]],
#
#         [[-0.8203125 ],
#          [-0.81510417],
#          [-0.81510417],
#          ...,
#          [-0.8125    ],
#          [-0.796875  ],
#          [-0.8046875 ]]],
#
#
#        [[[-0.4140625 ],
#          [-0.3984375 ],
#          [-0.328125  ],
#          ...,
#          [ 0.6171875 ],
#          [ 0.60416667],
#          [ 0.57552083]],
#
#         [[-0.36197917],
#          [-0.34895833],
#          [-0.328125  ],
#          ...,
#          [ 0.63020833],
#          [ 0.625     ],
#          [ 0.58333333]],
#
#         [[-0.42708333],
#          [-0.42447917],
#          [-0.36979167],
#          ...,
#          [ 0.63541667],
#          [ 0.63802083],
#          [ 0.5859375 ]],
#
#         ...,
#
#         [[-0.74479167],
#          [-0.79427083],
#          [-0.796875  ],
#          ...,
#          [-0.73697917],
#          [-0.7421875 ],
#          [-0.74479167]],
#
#         [[-0.75      ],
#          [-0.7890625 ],
#          [-0.79427083],
#          ...,
#          [-0.73697917],
#          [-0.73697917],
#          [-0.7421875 ]],
#
#         [[-0.75      ],
#          [-0.78125   ],
#          [-0.79166667],
#          ...,
#          [-0.7265625 ],
#          [-0.72916667],
#          [-0.734375  ]]]])

# %%
i = 1000
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')

# %%
i = 1000
plt.imshow(X_validation_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_validation[i])
plt.figure()
plt.imshow(X_validation_gray[i].squeeze(), cmap='gray')

# %%
i = 1000
plt.imshow(X_test_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_test[i])
plt.figure()
plt.imshow(X_test_gray[i].squeeze(), cmap='gray')

# %% [markdown]
# # Model Training

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import TensorBoard

# %%
cnn_model = Sequential()

cnn_model.add(Conv2D(filters = 6, kernel_size=(5,5), activation = 'relu', input_shape=(32,32,1)))
cnn_model.add(AveragePooling2D())

cnn_model.add(Conv2D(filters = 6, kernel_size=(5,5), activation = 'relu'))
cnn_model.add(AveragePooling2D())

cnn_model.add(Flatten())

cnn_model.add(Dense(units = 120, activation = 'relu'))

cnn_model.add(Dense(units = 84, activation = 'relu'))

cnn_model.add(Dense(units = 43, activation = 'softmax'))

# %%
cnn_model.compile(loss = 'sparse_categorical_crossentropy', optimizer = Adam(lr = 0.001), metrics = ['accuracy'])

# %%
history = cnn_model.fit(X_train_gray_norm, 
             y_train, 
             batch_size = 500,
             epochs = 50,
             verbose =1,
             validation_data = (X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 12s 156ms/step - loss: 3.5419 - accuracy: 0.0791 - val_loss: 3.1310 - val_accuracy: 0.1986
# Epoch 2/50
# 70/70 [==============================] - 9s 129ms/step - loss: 2.4475 - accuracy: 0.3592 - val_loss: 1.7611 - val_accuracy: 0.4921
# Epoch 3/50
# 70/70 [==============================] - 9s 133ms/step - loss: 1.3164 - accuracy: 0.6201 - val_loss: 1.2418 - val_accuracy: 0.6268
# Epoch 4/50
# 70/70 [==============================] - 9s 132ms/step - loss: 0.9239 - accuracy: 0.7285 - val_loss: 0.9854 - val_accuracy: 0.7061
# Epoch 5/50
# 70/70 [==============================] - 9s 132ms/step - loss: 0.7175 - accuracy: 0.7999 - val_loss: 0.8646 - val_accuracy: 0.7451
# Epoch 6/50
# 70/70 [==============================] - 9s 132ms/step - loss: 0.6063 - accuracy: 0.8236 - val_loss: 0.8043 - val_accuracy: 0.7596
# Epoch 7/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.5201 - accuracy: 0.8544 - val_loss: 0.7412 - val_accuracy: 0.7807
# Epoch 8/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.4489 - accuracy: 0.8795 - val_loss: 0.6893 - val_accuracy: 0.7925
# Epoch 9/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.4114 - accuracy: 0.8895 - val_loss: 0.6796 - val_accuracy: 0.8039
# Epoch 10/50
# 70/70 [==============================] - 10s 137ms/step - loss: 0.3660 - accuracy: 0.9018 - val_loss: 0.6591 - val_accuracy: 0.8154
# Epoch 11/50
# 70/70 [==============================] - 11s 150ms/step - loss: 0.3260 - accuracy: 0.9126 - val_loss: 0.6596 - val_accuracy: 0.8016
# Epoch 12/50
# 70/70 [==============================] - 10s 146ms/step - loss: 0.3014 - accuracy: 0.9204 - val_loss: 0.6057 - val_accuracy: 0.8254
# Epoch 13/50
# 70/70 [==============================] - 10s 144ms/step - loss: 0.2810 - accuracy: 0.9274 - val_loss: 0.6061 - val_accuracy: 0.8327
# Epoch 14/50
# 70/70 [==============================] - 10s 139ms/step - loss: 0.2688 - accuracy: 0.9295 - val_loss: 0.5740 - val_accuracy: 0.8451
# Epoch 15/50
# 70/70 [==============================] - 10s 141ms/step - loss: 0.2419 - accuracy: 0.9362 - val_loss: 0.6053 - val_accuracy: 0.8274
# Epoch 16/50
# 70/70 [==============================] - 10s 140ms/step - loss: 0.2283 - accuracy: 0.9414 - val_loss: 0.5983 - val_accuracy: 0.8404
# Epoch 17/50
# 70/70 [==============================] - 10s 145ms/step - loss: 0.2202 - accuracy: 0.9441 - val_loss: 0.5962 - val_accuracy: 0.8401
# Epoch 18/50
# 70/70 [==============================] - 10s 142ms/step - loss: 0.1995 - accuracy: 0.9476 - val_loss: 0.5691 - val_accuracy: 0.8424
# Epoch 19/50
# 70/70 [==============================] - 10s 149ms/step - loss: 0.1835 - accuracy: 0.9530 - val_loss: 0.6210 - val_accuracy: 0.8263
# Epoch 20/50
# 70/70 [==============================] - 10s 139ms/step - loss: 0.1735 - accuracy: 0.9542 - val_loss: 0.5910 - val_accuracy: 0.8485
# Epoch 21/50
# 70/70 [==============================] - 10s 136ms/step - loss: 0.1559 - accuracy: 0.9599 - val_loss: 0.6393 - val_accuracy: 0.8327
# Epoch 22/50
# 70/70 [==============================] - 9s 134ms/step - loss: 0.1562 - accuracy: 0.9586 - val_loss: 0.5675 - val_accuracy: 0.8526
# Epoch 23/50
# 70/70 [==============================] - 10s 146ms/step - loss: 0.1539 - accuracy: 0.9629 - val_loss: 0.5847 - val_accuracy: 0.8447
# Epoch 24/50
# 70/70 [==============================] - 10s 138ms/step - loss: 0.1466 - accuracy: 0.9626 - val_loss: 0.6447 - val_accuracy: 0.8354
# Epoch 25/50
# 70/70 [==============================] - 10s 141ms/step - loss: 0.1347 - accuracy: 0.9630 - val_loss: 0.6264 - val_accuracy: 0.8435
# Epoch 26/50
# 70/70 [==============================] - 9s 132ms/step - loss: 0.1253 - accuracy: 0.9692 - val_loss: 0.5750 - val_accuracy: 0.8562
# Epoch 27/50
# 70/70 [==============================] - 9s 129ms/step - loss: 0.1173 - accuracy: 0.9699 - val_loss: 0.6980 - val_accuracy: 0.8408
# Epoch 28/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.1107 - accuracy: 0.9728 - val_loss: 0.6311 - val_accuracy: 0.8474
# Epoch 29/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0976 - accuracy: 0.9755 - val_loss: 0.6252 - val_accuracy: 0.8512
# Epoch 30/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.1071 - accuracy: 0.9736 - val_loss: 0.6440 - val_accuracy: 0.8474
# Epoch 31/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.1011 - accuracy: 0.9723 - val_loss: 0.6525 - val_accuracy: 0.8467
# Epoch 32/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.0873 - accuracy: 0.9789 - val_loss: 0.6509 - val_accuracy: 0.8503
# Epoch 33/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0866 - accuracy: 0.9772 - val_loss: 0.6347 - val_accuracy: 0.8528
# Epoch 34/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0879 - accuracy: 0.9769 - val_loss: 0.6465 - val_accuracy: 0.8494
# Epoch 35/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.0803 - accuracy: 0.9806 - val_loss: 0.6302 - val_accuracy: 0.8571
# Epoch 36/50
# 70/70 [==============================] - 9s 129ms/step - loss: 0.0724 - accuracy: 0.9819 - val_loss: 0.6847 - val_accuracy: 0.8526
# Epoch 37/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0691 - accuracy: 0.9836 - val_loss: 0.7322 - val_accuracy: 0.8458
# Epoch 38/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0668 - accuracy: 0.9827 - val_loss: 0.6467 - val_accuracy: 0.8610
# Epoch 39/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0596 - accuracy: 0.9853 - val_loss: 0.7034 - val_accuracy: 0.8476
# Epoch 40/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0647 - accuracy: 0.9831 - val_loss: 0.6819 - val_accuracy: 0.8560
# Epoch 41/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0662 - accuracy: 0.9821 - val_loss: 0.7112 - val_accuracy: 0.8540
# Epoch 42/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0561 - accuracy: 0.9873 - val_loss: 0.7235 - val_accuracy: 0.8533
# Epoch 43/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.0511 - accuracy: 0.9874 - val_loss: 0.6995 - val_accuracy: 0.8562
# Epoch 44/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0480 - accuracy: 0.9875 - val_loss: 0.7610 - val_accuracy: 0.8442
# Epoch 45/50
# 70/70 [==============================] - 9s 130ms/step - loss: 0.0504 - accuracy: 0.9859 - val_loss: 0.7590 - val_accuracy: 0.8569
# Epoch 46/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.0469 - accuracy: 0.9888 - val_loss: 0.7768 - val_accuracy: 0.8549
# Epoch 47/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.0481 - accuracy: 0.9872 - val_loss: 0.7548 - val_accuracy: 0.8497
# Epoch 48/50
# 70/70 [==============================] - 9s 131ms/step - loss: 0.0423 - accuracy: 0.9892 - val_loss: 0.7685 - val_accuracy: 0.8576
# Epoch 49/50
# 70/70 [==============================] - 9s 132ms/step - loss: 0.0435 - accuracy: 0.9889 - val_loss: 0.7588 - val_accuracy: 0.8526
# Epoch 50/50
# 70/70 [==============================] - 9s 132ms/step - loss: 0.0504 - accuracy: 0.9844 - val_loss: 0.7845 - val_accuracy: 0.8569

# %% [markdown]
# # Model Evaluation

# %%
score = cnn_model.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 3s 7ms/step - loss: 1.2581 - accuracy: 0.8445
# Test Accuracy: 0.8444972038269043

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label ='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
epochs = range(len(accuracy))

plt.plot(epochs, loss, 'ro', label ='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()

# %%
predicted_classes = cnn_model.predict_classes(X_test_gray_norm)
y_true = y_test
# Out:
# C:\Users\janhv\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize=(25,25))
sns.heatmap(cm, annot = True)
# Out:
# <AxesSubplot:>

# %%
L = 7
W = 7

fig, axes = plt.subplots(L, W, figsize =(12,12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(predicted_classes[i], y_true[i]))
    axes[i].axis('off')
    
plt.subplots_adjust(wspace =1)
